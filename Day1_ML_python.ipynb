# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data preparation

# %% [markdown]
# # 1.) Load the dataset using pandas

# %%
data=pd.read_csv('houses_traindata.csv')
data
# Out:
#      beds  baths  sqft  zip_code    price
# 0       3    2.5  2590     98144   795000
# 1       4    2.0  2240     98106   915000
# 2       4    3.0  2040     98107   950000
# 3       4    3.0  3800     98199  1950000
# 4       2    2.0  1042     98102   950000
# ..    ...    ...   ...       ...      ...
# 294     4    3.0  2980     98105  1090000
# 295     3    1.5  1390     98168   412000
# 296     2    1.0   720     98106   525000
# 297     1    1.0   712     98133   325000
# 298     4    2.5  1850     98108   945000
#
# [299 rows x 5 columns]

# %%
data.head()
# Out:
#    beds  baths  sqft  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000

# %% [markdown]
# # 2.)Explore and clean the data.Handle missing values and outliers.

# %%
data.tail()
# Out:
#      beds  baths  sqft  zip_code    price
# 294     4    3.0  2980     98105  1090000
# 295     3    1.5  1390     98168   412000
# 296     2    1.0   720     98106   525000
# 297     1    1.0   712     98133   325000
# 298     4    2.5  1850     98108   945000

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'beds'}>,
#         <Axes: title={'center': 'baths'}>],
#        [<Axes: title={'center': 'sqft'}>,
#         <Axes: title={'center': 'zip_code'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >]], dtype=object)

# %%
data.describe()
# Out:
#              beds       baths          sqft      zip_code         price
# count  299.000000  299.000000    299.000000    299.000000  2.990000e+02
# mean     2.953177    2.234114   1819.959866  98124.421405  9.430015e+05
# std      1.427609    1.067538   1086.193714     23.424511  5.983570e+05
# min      1.000000    1.000000    474.000000  98101.000000  2.899000e+05
# 25%      2.000000    1.500000   1095.000000  98107.000000  5.815000e+05
# 50%      3.000000    2.000000   1590.000000  98117.000000  7.990000e+05
# 75%      4.000000    3.000000   2380.000000  98133.000000  1.092500e+06
# max     15.000000    8.500000  11010.000000  98199.000000  5.495000e+06

# %%
data.head(10)
# Out:
#    beds  baths  sqft  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000
# 5     2    2.0  1190     98107   740000
# 6     1    1.0   670     98133   460000
# 7     5    3.5  4510     98105  3150000
# 8     3    2.5  1520     98108   565000
# 9     4    2.0  2340     98178   699000

# %%
data.isnull().sum()
# Out:
# beds        0
# baths       0
# sqft        0
# zip_code    0
# price       0
# dtype: int64

# %% [markdown]
# # 3.) Split the dataset into training and testing sets

# %%
a=data.iloc[:,:1]
a.head(20)
# Out:
#     beds
# 0      3
# 1      4
# 2      4
# 3      4
# 4      2
# 5      2
# 6      1
# 7      5
# 8      3
# 9      4
# 10     3
# 11     3
# 12     3
# 13     4
# 14     5
# 15     2
# 16     3
# 17     1
# 18     3
# 19     4

# %%
b=data.iloc[:,1:2]
b.head(20)
# Out:
#     baths
# 0     2.5
# 1     2.0
# 2     3.0
# 3     3.0
# 4     2.0
# 5     2.0
# 6     1.0
# 7     3.5
# 8     2.5
# 9     2.0
# 10    2.0
# 11    2.0
# 12    2.5
# 13    3.0
# 14    1.5
# 15    1.5
# 16    3.5
# 17    1.0
# 18    2.5
# 19    3.5

# %%
c=data.iloc[:,2:3]
c.tail(10)
# Out:
#      sqft
# 289  2360
# 290  1396
# 291   615
# 292  2340
# 293  2140
# 294  2980
# 295  1390
# 296   720
# 297   712
# 298  1850

# %%
d=data.iloc[:,3:4]
d.tail(5)
# Out:
#      zip_code
# 294     98105
# 295     98168
# 296     98106
# 297     98133
# 298     98108

# %%
e=data.iloc[:,4:]
e.head(10)
# Out:
#      price
# 0   795000
# 1   915000
# 2   950000
# 3  1950000
# 4   950000
# 5   740000
# 6   460000
# 7  3150000
# 8   565000
# 9   699000

# %%
type(e)
# Out:
# pandas.core.frame.DataFrame

# %%
type(c)
# Out:
# pandas.core.frame.DataFrame

# %%
data.corr()
# Out:
#               beds     baths      sqft  zip_code     price
# beds      1.000000  0.675483  0.846992  0.047956  0.558549
# baths     0.675483  1.000000  0.649270 -0.048645  0.577753
# sqft      0.846992  0.649270  1.000000  0.018368  0.779648
# zip_code  0.047956 -0.048645  0.018368  1.000000 -0.099198
# price     0.558549  0.577753  0.779648 -0.099198  1.000000

# %%
#visualize the dataset when comparing no of bedrooms and price of the house
plt.scatter(a,e)
plt.title('Prices of houses based on no of bedrooms')
plt.xlabel('no of bedrooms')
plt.ylabel('price of house')
plt.show()

# %%
import sklearn
from sklearn.model_selection import train_test_split
atrain,atest,btrain,btest,ctrain,ctest,dtrain,dtest,etrain,etest=train_test_split(a,b,c,d,e,test_size=0.2)

# %%
data.shape
# Out:
# (299, 5)

# %%
atrain.shape
# Out:
# (239, 1)

# %%
atest.shape
# Out:
# (60, 1)

# %%
btrain.shape
# Out:
# (239, 1)

# %%
btest.shape
# Out:
# (60, 1)

# %%
etrain.shape
# Out:
# (239, 1)

# %%
etest.shape
# Out:
# (60, 1)

# %%
etrain
# Out:
#       price
# 180  450000
# 35   335000
# 169  799000
# 150  600000
# 241  793000
# ..      ...
# 102  354000
# 168  685000
# 209  670000
# 229  750000
# 260  620000
#
# [239 rows x 1 columns]

# %%
etest
# Out:
#        price
# 200  2485000
# 52    800000
# 272   910000
# 3    1950000
# 16    700000
# 72   1850000
# 248  1067000
# 193   825000
# 208  1300000
# 152   865000
# 60    770000
# 205   685000
# 97   1585000
# 14   1330000
# 214   905000
# 45   1395000
# 82    420000
# 159   680000
# 165   675000
# 250   780000
# 17    330000
# 189   325100
# 166   580000
# 129   749950
# 147   605000
# 115   630000
# 53   1100000
# 284   385000
# 76    509950
# 188   659950
# 154   543750
# 135   555000
# 186  3200000
# 156   905000
# 61   5495000
# 59    860000
# 167   630000
# 267   750000
# 266   330000
# 255   940000
# 11   1050000
# 43    480000
# 182   455000
# 161   389200
# 148  1295000
# 194   775000
# 125   800000
# 137   845000
# 106   346600
# 282  1400000
# 117   375000
# 221   863000
# 69   1605000
# 88    360000
# 133   435000
# 128  1606500
# 233  1025000
# 226  2095000
# 204   859990
# 122   950000

# %%
ctest
# Out:
#      sqft
# 297   712
# 199   900
# 46   1240
# 110  2650
# 246  2867
# 61   4040
# 177  2230
# 209  1131
# 48   3590
# 292  2340
# 200  3960
# 70   2031
# 25    889
# 173  2350
# 147  1071
# 40   1500
# 8    1520
# 140  1290
# 150  1670
# 207  3340
# 206  1563
# 156  2030
# 212   519
# 218  2650
# 37   2510
# 112  2550
# 288  1128
# 186  3956
# 163  1030
# 55   2820
# 195  3400
# 49   2478
# 122  2080
# 210  1201
# 165   792
# 63   2820
# 201   889
# 234  3590
# 158  1720
# 250  1300
# 57   1092
# 74   8660
# 284   500
# 249  2220
# 130   868
# 108  1050
# 76    635
# 144  1188
# 21   2668
# 194  3020
# 35    474
# 54    780
# 103  2400
# 135   866
# 268  2760
# 204  1467
# 178  3130
# 113  3800
# 238  1088
# 169  1806

# %%
btrain
# Out:
#      baths
# 180    2.0
# 35     1.0
# 169    2.0
# 150    3.5
# 241    1.0
# ..     ...
# 102    1.0
# 168    1.5
# 209    1.5
# 229    2.0
# 260    1.0
#
# [239 rows x 1 columns]

# %% [markdown]
# # Implement Simple linear regression
# a.) Choose a feature(ex-square footage) as an independent variable(X) and house prices as the dependant variable(Y)
# b.) Implement simple linear regression model using sklearn to predict house prices based on the selected feature
# c.)Visualize the data and the regression line

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
#train the data
print("Training Started.......\n")
print()
lin_reg.fit(ctrain,etrain)
print('Training completed.....')
print()
#test the data
print('Testing invoked......\n')
epredict=lin_reg.predict(ctest)
print('Predicted price\n',epredict)
print('\nTesting is also completed....\n')
# Out:
# Training Strated.......
#
#
# Training completed.....
#
# Testing invoked......
#
# Predicted price
#  [[1751360.87881753]
#  [1176816.16277399]
#  [ 878674.0398541 ]
#  [1689247.93654256]
#  [ 742025.56684915]
#  [1238929.10504897]
#  [ 959420.86481157]
#  [1068118.51379278]
#  [1141877.63274432]
#  [ 862369.39250691]
#  [ 735814.27262165]
#  [ 955538.80591938]
#  [1394211.46073641]
#  [1207872.63391148]
#  [ 866251.4513991 ]
#  [ 805303.12679178]
#  [ 553745.71057812]
#  [ 529676.94544657]
#  [ 521524.62177297]
#  [ 718733.21349603]
#  [ 427578.79658207]
#  [ 485809.67996486]
#  [ 599942.21139513]
#  [ 659337.71244558]
#  [ 629834.06486497]
#  [ 955538.80591938]
#  [ 815784.68580068]
#  [ 408168.50212114]
#  [ 460576.29716565]
#  [ 745907.62574133]
#  [ 881779.68696785]
#  [ 550251.85757515]
#  [1749808.05526066]
#  [1002123.51262561]
#  [1782417.34995502]
#  [ 796374.39133975]
#  [ 846841.15693817]
#  [ 676030.56568198]
#  [ 697381.88958901]
#  [1203990.57501929]
# ...

# %%
etrain
# Out:
#       price
# 180  450000
# 35   335000
# 169  799000
# 150  600000
# 241  793000
# ..      ...
# 102  354000
# 168  685000
# 209  670000
# 229  750000
# 260  620000
#
# [239 rows x 1 columns]

# %%
etest
# Out:
#        price
# 200  2485000
# 52    800000
# 272   910000
# 3    1950000
# 16    700000
# 72   1850000
# 248  1067000
# 193   825000
# 208  1300000
# 152   865000
# 60    770000
# 205   685000
# 97   1585000
# 14   1330000
# 214   905000
# 45   1395000
# 82    420000
# 159   680000
# 165   675000
# 250   780000
# 17    330000
# 189   325100
# 166   580000
# 129   749950
# 147   605000
# 115   630000
# 53   1100000
# 284   385000
# 76    509950
# 188   659950
# 154   543750
# 135   555000
# 186  3200000
# 156   905000
# 61   5495000
# 59    860000
# 167   630000
# 267   750000
# 266   330000
# 255   940000
# 11   1050000
# 43    480000
# 182   455000
# 161   389200
# 148  1295000
# 194   775000
# 125   800000
# 137   845000
# 106   346600
# 282  1400000
# 117   375000
# 221   863000
# 69   1605000
# 88    360000
# 133   435000
# 128  1606500
# 233  1025000
# 226  2095000
# 204   859990
# 122   950000

# %%
diff=etest-epredict
diff
# Out:
#             price
# 297 -1.664875e+05
# 199 -8.461310e+04
# 46   5.313840e+04
# 110 -1.503039e+05
# 246  4.202904e+05
# 61   3.709033e+06
# 177  1.230619e+05
# 209  1.553571e+04
# 48   7.390679e+05
# 292 -1.997244e+05
# 200  7.301504e+05
# 70   4.754662e+05
# 25   1.196655e+05
# 173  4.541859e+05
# 147 -2.612631e+04
# 40   2.720072e+05
# 8   -2.407721e+05
# 140  7.869009e+04
# 150 -2.641171e+05
# 207 -5.336906e+05
# 206  1.745232e+04
# 156 -9.914488e+04
# 212 -6.241698e+04
# 218 -2.453039e+05
# 37  -1.908486e+05
# 112  3.535927e+05
# 288 -1.733474e+05
# 186  1.446706e+06
# 163 -4.017870e+04
# 55  -4.464282e+05
# 195 -7.805285e+05
# 49   4.015983e+05
# 122 -7.359319e+04
# 210  1.825808e+04
# 165  1.523952e+05
# 63  -4.114282e+05
# 201  1.626655e+05
# 234  1.140679e+05
# 158 -5.856537e+04
# 250  5.980043e+04
# 57   1.897054e+05
# 74   5.170093e+05
# 284 -2.402663e+04
# 249 -5.270485e+05
# 130 -1.371662e+05
# 108 -2.230080e+05
# 76   4.841294e+04
# 144  6.733646e+05
# 21  -3.930530e+04
# ...

# %%
#Visualise the training dataset
plt.scatter(ctrain,etrain,color='red')
plt.plot(ctrain,lin_reg.predict(ctrain),color='green')
plt.title('Prices according to squarefoot of the house(training dataset)')
plt.xlabel('sqft')
plt.ylabel('price')
plt.show()

# %%
#Visualise the test dataset
plt.scatter(ctest,etest,color='green')
plt.plot(ctest,lin_reg.predict(ctest),color='red')
plt.title('Prices according to squarefoot of the house(testing dataset)')
plt.xlabel('sqft')
plt.ylabel('price')
plt.show()

# %% [markdown]
# # Evaluate the Simple linear regression model
# a.)Use scikit learn to calculate the R-squared value to assess the goodness of fit
# b.)Interpret the R-squared value and discuss the model's performance

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

print('Mean Squared Error ; \t',mean_squared_error(etest,epredict))
print()
print('RMSE:\t',np.sqrt(mean_squared_error(etest,epredict)))
print()
print('Variance Score:\t',explained_variance_score(etest,epredict))

#Coefficient of determination- R_square
print()
print('R-Square:\t',r2_score(etest,epredict))
# Out:
# Mean Squared Error ; 	 330774002692.4018
#
# RMSE:	 575129.5529638533
#
# Variance Score:	 0.5053712341233607
#
# R-Square:	 0.4859785408110462

# %% [markdown]
# # Implement Multiple linear Regression
# 1.)Select multiple features (ex-squarefootage,number of bedrooms, number of bathrooms)as independendent variables(X) and house prices as the dependant variable(Y)
# 2.) Implement a multiple linear regression model using sci-kit learn to predict house prices based on the selected features

# %%
df=pd.read_csv('houses_traindata.csv')
df.head()
# Out:
#    beds  baths  sqft  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000

# %%
df.isna().sum()
# Out:
# beds        0
# baths       0
# sqft        0
# zip_code    0
# price       0
# dtype: int64

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#    beds  baths  sqft  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000

# %%
x=df.iloc[:,:-1]
x.head()
# Out:
#    beds  baths  sqft  zip_code
# 0     3    2.5  2590     98144
# 1     4    2.0  2240     98106
# 2     4    3.0  2040     98107
# 3     4    3.0  3800     98199
# 4     2    2.0  1042     98102

# %%
y=data.iloc[:,-1:]
y.head()
# Out:
#      price
# 0   795000
# 1   915000
# 2   950000
# 3  1950000
# 4   950000

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
mul_reg=LinearRegression()
#train the model
mul_reg.fit(xtrain,ytrain)
print("Training completed")
print()
#test the model
ypred=mul_reg.predict(xtest)
print("Testing completed")
# Out:
# Training completed
#
# Testing completed

# %% [markdown]
# # Evaluate the Multiple linear Regression model
# Calculate MAE,MSE,RMSE to assess the model's accuracy

# %%
from sklearn.metrics import mean_squared_error,r2_score
print()
print('Mean Squared Error ; \t',mean_squared_error(ytest,ypred))
print()
print('RMSE: ', np.sqrt(mean_squared_error(ytest,ypred)))
print()
print('R-square: ',r2_score(ytest,ypred))
print()
# Out:
# Mean Squared Error ; 	 63767206981.165184
#
# RMSE:  252521.6960602894
#
# R-square:  0.519759977857969
