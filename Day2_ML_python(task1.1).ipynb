# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %% [markdown]
# # Data preparation

# %% [markdown]
# # 1.) Load the dataset using pandas

# %%
data=pd.read_csv('houses_traindata.csv')
data
# Out:
#      beds  baths  sqft  zip_code    price
# 0       3    2.5  2590     98144   795000
# 1       4    2.0  2240     98106   915000
# 2       4    3.0  2040     98107   950000
# 3       4    3.0  3800     98199  1950000
# 4       2    2.0  1042     98102   950000
# ..    ...    ...   ...       ...      ...
# 294     4    3.0  2980     98105  1090000
# 295     3    1.5  1390     98168   412000
# 296     2    1.0   720     98106   525000
# 297     1    1.0   712     98133   325000
# 298     4    2.5  1850     98108   945000
#
# [299 rows x 5 columns]

# %% [markdown]
# # 2.)Explore and clean the data.Handle missing values and outliers.

# %%
data.head()
# Out:
#    beds  baths  sqft  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000

# %%
data.tail()
# Out:
#      beds  baths  sqft  zip_code    price
# 294     4    3.0  2980     98105  1090000
# 295     3    1.5  1390     98168   412000
# 296     2    1.0   720     98106   525000
# 297     1    1.0   712     98133   325000
# 298     4    2.5  1850     98108   945000

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'beds'}>,
#         <Axes: title={'center': 'baths'}>],
#        [<Axes: title={'center': 'sqft'}>,
#         <Axes: title={'center': 'zip_code'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >]], dtype=object)

# %%
data.describe()
# Out:
#              beds       baths          sqft      zip_code         price
# count  299.000000  299.000000    299.000000    299.000000  2.990000e+02
# mean     2.953177    2.234114   1819.959866  98124.421405  9.430015e+05
# std      1.427609    1.067538   1086.193714     23.424511  5.983570e+05
# min      1.000000    1.000000    474.000000  98101.000000  2.899000e+05
# 25%      2.000000    1.500000   1095.000000  98107.000000  5.815000e+05
# 50%      3.000000    2.000000   1590.000000  98117.000000  7.990000e+05
# 75%      4.000000    3.000000   2380.000000  98133.000000  1.092500e+06
# max     15.000000    8.500000  11010.000000  98199.000000  5.495000e+06

# %%
data.head(10)
# Out:
#    beds  baths  sqft  zip_code    price
# 0     3    2.5  2590     98144   795000
# 1     4    2.0  2240     98106   915000
# 2     4    3.0  2040     98107   950000
# 3     4    3.0  3800     98199  1950000
# 4     2    2.0  1042     98102   950000
# 5     2    2.0  1190     98107   740000
# 6     1    1.0   670     98133   460000
# 7     5    3.5  4510     98105  3150000
# 8     3    2.5  1520     98108   565000
# 9     4    2.0  2340     98178   699000

# %%
data.isnull().sum()
# Out:
# beds        0
# baths       0
# sqft        0
# zip_code    0
# price       0
# dtype: int64

# %% [markdown]
# # 3.) Split the dataset into training and testing sets

# %%
x=data.iloc[:,:-1]
x.head(20)
# Out:
#     beds  baths  sqft  zip_code
# 0      3    2.5  2590     98144
# 1      4    2.0  2240     98106
# 2      4    3.0  2040     98107
# 3      4    3.0  3800     98199
# 4      2    2.0  1042     98102
# 5      2    2.0  1190     98107
# 6      1    1.0   670     98133
# 7      5    3.5  4510     98105
# 8      3    2.5  1520     98108
# 9      4    2.0  2340     98178
# 10     3    2.0  1320     98103
# 11     3    2.0  1800     98177
# 12     3    2.5  2490     98103
# 13     4    3.0  2650     98115
# 14     5    1.5  2560     98199
# 15     2    1.5   900     98133
# 16     3    3.5  1360     98103
# 17     1    1.0   550     98122
# 18     3    2.5  2974     98119
# 19     4    3.5  1989     98117

# %%
y=data.iloc[:,-1:]
y.head(20)
# Out:
#       price
# 0    795000
# 1    915000
# 2    950000
# 3   1950000
# 4    950000
# 5    740000
# 6    460000
# 7   3150000
# 8    565000
# 9    699000
# 10   899000
# 11  1050000
# 12   935625
# 13  1511000
# 14  1330000
# 15   549755
# 16   700000
# 17   330000
# 18  1750000
# 19   980000

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
print(len(xtest),len(ytest))
# Out:
# 60 60

# %%
xtrain.shape
# Out:
# (239, 4)

# %%
xtest.shape
# Out:
# (60, 4)

# %%
ytrain.shape
# Out:
# (239, 1)

# %%
ytest.shape
# Out:
# (60, 1)

# %%
data.shape
# Out:
# (299, 5)

# %%
xtrain
# Out:
#      beds  baths  sqft  zip_code
# 100     3    3.0  1450     98117
# 252     3    2.0  1460     98106
# 5       2    2.0  1190     98107
# 142     1    1.0   630     98146
# 62      5    3.0  2320     98168
# ..    ...    ...   ...       ...
# 59      3    2.5  1500     98105
# 30      3    2.5  1690     98108
# 87      2    1.5  1810     98115
# 119     4    3.5  2661     98108
# 227     2    2.0  1140     98133
#
# [239 rows x 4 columns]

# %%
xtest
# Out:
#      beds  baths  sqft  zip_code
# 191     1    1.0   956     98104
# 285     3    2.0  1580     98126
# 90      3    5.5  1530     98103
# 79      3    3.5  1510     98103
# 96      3    2.5  1820     98118
# 26      1    1.0   508     98109
# 120     2    2.0   843     98103
# 187     6    5.0  3620     98119
# 158     3    1.5  1720     98117
# 143     3    2.0  1880     98144
# 264     1    1.0   613     98122
# 202     5    3.5  3310     98115
# 155     3    1.0  1200     98105
# 69      3    2.0  2702     98103
# 254     3    2.5  1540     98122
# 41      5    4.0  2920     98133
# 209     2    1.5  1131     98144
# 117     1    1.0   589     98121
# 277     2    1.5   822     98144
# 57      2    2.0  1092     98122
# 290     3    2.5  1396     98136
# 179     5    3.0  3750     98107
# 124     1    1.0   699     98115
# 28      4    2.0  2000     98125
# 171     5    3.5  3820     98118
# 10      3    2.0  1320     98103
# 185     2    1.0  1422     98117
# 80      3    1.0  1120     98106
# 89      2    2.0  1006     98121
# 38      1    1.0   750     98199
# 110     3    3.5  2650     98136
# 92      3    2.0  1960     98105
# 40      3    2.5  1500     98103
# 145     2    1.5  1300     98133
# 223     2    2.0  1140     98117
# 34      4    1.5  1940     98118
# 99      1    1.0   800     98122
# 270     4    3.0  2380     98115
# 208     4    3.0  2390     98119
# 54      2    1.0   780     98103
# 44      2    2.0  1280     98112
# 163     2    2.0  1030     98122
# 63      5    3.0  2820     98136
# 242     2    2.0  1128     98144
# 271     2    2.5  1884     98116
# 37      5    5.0  2510     98133
# 1       4    2.0  2240     98106
# 184     2    1.5  1230     98122
# 221     2    1.0   980     98107
# 279     3    3.0  2380     98136
# 0       3    2.5  2590     98144
# 95      3    1.0  2200     98105
# 169     3    2.0  1806     98126
# 109     3    2.0  1720     98199
# 82      2    2.0   875     98115
# 234     3    2.5  3590     98103
# 108     3    1.0  1050     98106
# 238     2    2.5  1088     98107
# 31      4    5.5  3000     98126
# 249     2    2.0  2220     98126

# %%
ytrain
# Out:
#        price
# 100   750000
# 252   583000
# 5     740000
# 142   459000
# 62    560000
# ..       ...
# 59    860000
# 30    760000
# 87    925000
# 119  1165000
# 227   665000
#
# [239 rows x 1 columns]

# %%
ytest
# Out:
#        price
# 191   870000
# 285   942000
# 90    635000
# 79    660000
# 96    690000
# 26    325000
# 120   346250
# 187  1420000
# 158   825000
# 143   911000
# 264   325000
# 202  1575000
# 155  1099950
# 69   1605000
# 254   852500
# 41    948000
# 209   670000
# 117   375000
# 277   400000
# 57    829000
# 290   780000
# 179  1580000
# 124   335000
# 28    907200
# 171  1350000
# 10    899000
# 185   715000
# 80    615000
# 89    928000
# 38    375000
# 110  1095000
# 92    950000
# 40   1070000
# 145   570288
# 223   590000
# 34    520000
# 99    450000
# 270  1399999
# 208  1300000
# 54    750000
# 44    776000
# 163   575000
# 63    900000
# 242   625000
# 271   925000
# 37   1000000
# 1     915000
# 184   650000
# 221   863000
# 279  1230000
# 0     795000
# 95   1250000
# 169   799000
# 109   855000
# 82    420000
# 234  1725000
# 108   399950
# 238   835000
# 31   1484000
# 249   551000

# %% [markdown]
# # Implement and evaluate base regression

# %%
print('**********Base Regression***********')
from sklearn.linear_model import LinearRegression
base_reg=LinearRegression()
#train the data
print("Training Started.......\n")
print()
base_reg.fit(xtrain,ytrain)
print('Training completed.....')
print()
#test the data
print('Testing invoked......\n')
ypredict=base_reg.predict(xtest)
print('Predicted price\n',ypredict)
print('\nTesting is also completed....\n')
# Out:
# **********Base Regression***********
# Training Started.......
#
#
# Training completed.....
#
# Testing invoked......
#
# Predicted price
#  [[ 719306.54144114]
#  [ 768784.17077962]
#  [1356456.92709723]
#  [1017344.39777902]
#  [1006280.69921607]
#  [ 447749.32741725]
#  [ 600268.27437237]
#  [1810631.24597496]
#  [ 785999.6443167 ]
#  [ 909849.17227885]
#  [ 484323.11394286]
#  [1609982.12582383]
#  [ 422955.38584372]
#  [1468904.95226783]
#  [ 834885.93395874]
#  [1429365.44914985]
#  [ 608524.5616374 ]
#  [ 472197.38484386]
#  [ 427810.77538511]
#  [ 709596.43549189]
#  [ 723925.69668078]
#  [1800737.58414158]
#  [ 547990.91221786]
#  [ 797754.64207762]
#  [1902516.71887648]
#  [ 660664.00534001]
#  [ 748435.28480729]
#  [ 374258.35193223]
#  [ 661210.98229048]
#  [ 417352.83619049]
#  [1621015.78042686]
#  [1031137.34528998]
#  [ 847788.13311991]
#  [ 728374.77600566]
#  [ 747219.94562927]
#  [ 694182.67740309]
#  [ 593687.12050977]
#  [1202802.51417375]
#  [1201009.68423411]
#  [ 399715.79394829]
#  [ 838648.20766053]
#  [ 673336.71138948]
#  [1201443.22171366]
#  [ 688624.01988924]
#  [1266100.8890233 ]
#  [1353291.32472816]
#  [ 974410.43395934]
#  [ 708449.60230175]
#  [ 509041.47335473]
#  [1381256.56927252]
#  [1406935.45770833]
#  [1007789.64555994]
#  [ 900956.71347547]
#  [ 711209.56834319]
#  [ 596059.45307288]
#  [2070091.73592678]
#  [ 333319.95375207]
#  [ 817765.45649701]
#  [1953656.33587646]
#  [1361648.30791497]]
#
# Testing is also completed....

# %%
print('********Performance metrics of Linear Regression model*****************')
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

print('Mean Squared Error ; \t',mean_squared_error(ytest,ypredict))
print()
print('RMSE:\t',np.sqrt(mean_squared_error(ytest,ypredict)))
print()
print('Variance Score:\t',explained_variance_score(ytest,ypredict))
print()
print("Base Train_score:\t", base_reg.score(xtrain,ytrain))
print()
print("Base Test_score:\t", base_reg.score(xtest,ytest))
print()
print("Base R-Square:\t",r2_score(ytest,ypredict))
# Out:
# ********Performance metrics of Linear Regression model*****************
# Mean Squared Error ; 	 83466463601.90677
#
# RMSE:	 288905.63096261513
#
# Variance Score:	 0.39067120559589885
#
# Base Train_score:	 0.6963123893641012
#
# Base Test_score:	 0.3280723572894447
#
# Base R-Square:	 0.3280723572894447

# %% [markdown]
# # Implement and Evaluate Lasso Regression

# %%
print("*************Lasso Regression Model*************")
print()
lr=Lasso(alpha=0.01)
lr.fit(xtrain,ytrain)
lr_pred=lr.predict(xtest)
print("Lasso Train_score:\t", lr.score(xtrain,ytrain))
print()
print("Lasso Test_score:\t", lr.score(xtest,ytest))
print()
print("Lasso R-Square:\t",r2_score(ytest,lr_pred))
# Out:
# *************Lasso Regression Model*************
#
# Lasso Train_score:	 0.6963123893640997
#
# Lasso Test_score:	 0.3280724212460535
#
# Lasso R-Square:	 0.3280724212460535

# %%
#Build lasso model with alpha=0.00001
print("*************Lasso Regression Model*************")
print()
lr1=Lasso(alpha=0.00001)
lr1.fit(xtrain,ytrain)
lr1_pred=lr1.predict(xtest)
print("Lasso Train_score:\t", lr1.score(xtrain,ytrain))
print()
print("Lasso Test_score:\t", lr1.score(xtest,ytest))
print()
print("Lasso R-Square:\t",r2_score(ytest,lr1_pred))
# Out:
# *************Lasso Regression Model*************
#
# Lasso Train_score:	 0.6963123893641028
#
# Lasso Test_score:	 0.3280723573534403
#
# Lasso R-Square:	 0.3280723573534403

# %%
base_reg.coef_
# Out:
# array([[-218570.21091698,  163707.92206195,     584.83425972,
#           -1910.2931342 ]])

# %%
lr.coef_
# Out:
# array([-218570.18666636,  163707.89881015,     584.83424703,
#          -1910.29325611])

# %%
lr1.coef_
# Out:
# array([-218570.21089273,  163707.9220387 ,     584.8342597 ,
#          -1910.29313432])

# %% [markdown]
# # Implement and Evaluate Ridge Regression

# %%
#build bridge model
print('***********Ridge Regression model*****************')
rr=Ridge(alpha=0.01)
rr.fit(xtrain,ytrain)
rr_pred=rr.predict(xtest)
print('Ridge Train score:\t',rr.score(xtrain,ytrain))
print()
print('Ridge Test score:\t',rr.score(xtest,ytest))
print()
print('Ridge R-square:\t',r2_score(ytest,rr_pred))
# Out:
# ***********Ridge Regression model*****************
# Ridge Train score:	 0.6963123886181903
#
# Ridge Test score:	 0.32812223971030763
#
# Ridge R-square:	 0.32812223971030763

# %%
#Build Ridge model with alpha=100
print('***********Ridge Regression model*****************')
rr100=Ridge(alpha=100)
rr100.fit(xtrain,ytrain)
rr100_pred=rr.predict(xtest)
print('Ridge Train score:\t',rr100.score(xtrain,ytrain))
print()
print('Ridge Test score:\t',rr100.score(xtest,ytest))
print()
print('Ridge R-square:\t',r2_score(ytest,rr100_pred))
# Out:
# ***********Ridge Regression model*****************
# Ridge Train score:	 0.677436585506532
#
# Ridge Test score:	 0.5196112378413221
#
# Ridge R-square:	 0.5196112378413221

# %%
base_reg.coef_
# Out:
# array([[-218570.21091698,  163707.92206195,     584.83425972,
#           -1910.2931342 ]])

# %%
rr.coef_
# Out:
# array([[-113358.68692787,   78232.31942158,     520.49231985,
#           -2460.54160323]])

# %%
rr100.coef_
# Out:
# array([[-113358.68692787,   78232.31942158,     520.49231985,
#           -2460.54160323]])
